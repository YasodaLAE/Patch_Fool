# %% [markdown]
# <a href="https://colab.research.google.com/github/YasodaLAE/Patch_Fool/blob/main/PatchFool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install torch==1.7.1 torchvision==0.8.2 numpy tqdm timm ml-collections seaborn matplotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.7.1 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1)
# ERROR: No matching distribution found for torch==1.7.1
